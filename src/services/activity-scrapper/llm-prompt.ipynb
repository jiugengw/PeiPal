# %%
# genders = ['male', 'female']
# dates_text = ['{} to {}', '{}, {} and {}'] # For more dates, add "{}, " to the front
# pax_text = ['by myself', 'with {} other friend(s)']

# # Extracted info from speech
# pax = 2
# date_ranges = "2/8/2026, 5/8/2026 and 6/8/2026"
# activity = "mahjong"

# info = {
#     'gender': genders[0],
#     'age': 65,
#     'location': 'Bishan',
#     'activity': f"for {activity}" if activity is not None else '',
#     'date_range': date_ranges,
#     'pax': pax[0] if pax <= 1 else pax[1].format(pax - 1),
# }

prompt = f"You are an AI assistant, and you will be tasked to search online for a bunch of activities available"
f"from now till 1 month from now, suitable for people aged 65."
f"Recommend me the top 20 activities which is the most fitting, based in Singapore."
f"For each activity recommended, provide me the activity title, name of activity summarized to a few words, location, summarized description, slots availability"
